# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
import os
from parser import Parser
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist
from scipy.cluster import hierarchy
import numpy as np

def hierarchy_draw(Z, labels, level):
        """Рисуем дендрограмму и сохраняем её"""
        plt.figure()
        hierarchy.dendrogram(Z, labels = labels, color_threshold = level,
                             leaf_font_size = 10, count_sort = True)
        plt.rcParams["figure.figsize"] = (20, 25) 
        plt.show()

dir_path = 'Wiki-documents/'

print('Preprocessing of texts...')
        
corpus_of_texts = []

parser = Parser()

directories = [x[0] for x in os.walk(dir_path)]
directories = directories[1:]

file_names = []

y = []
k = 1
for i in range(len(directories)):
    for file in os.listdir(directories[i] + '/'):
        if file.endswith(".txt"):
            file_name = os.path.join(directories[i] + "/", file)
            print(file_name)
            y.append(k)
            file_names.append(file[:-4])
            text = parser.text_preprocessing(file_name)
            corpus_of_texts.append(text)
            
    k += 1
            

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus_of_texts)

lsa = TruncatedSVD(n_components = 2, algorithm = "arpack")

X = lsa.fit_transform(X)

for i in range(len(X)):
    marker = 'o'
    color = 'red'
    if y[i] == 1:
        marker = 'D'
        color = 'blue'
    if y[i] == 2:
        marker = '>'
        color = 'green'
    plt.plot(X[i, 0], X[i, 1], marker = marker, markersize = 5.0, color = color)

plt.show()

dist = pdist(X, 'cosine')
Z = hierarchy.linkage(dist, method='average')

print(Z)
print(len(file_names))
"""
def check(c):
    C = hierarchy.fcluster(Z, t = c)  
    if len(set(C)) <= 3:
        return True
    return False


def bs(l, r, EPS):  
    l = np.float128(l)
    r = np.float128(r)
    
    
    while (l < r):
        c = (l+r)/2
        print(c)
        if check(c) == True:
            r = c
        else:
            l = c + EPS
            
    return l

    
t = bs(1, 1.16, EPS = 1E-18)
"""
C = hierarchy.fcluster(Z, t = 3, criterion = 'maxclust')
hierarchy_draw(Z = Z, labels = file_names, level = 0.1)

Q = 0.0
for i in range(len(y)):
    for j in range(i+1, len(y)):
        if y[i] == y[j] and C[i] == C[j]:
            Q += 1
        if y[i] != y[j] and C[i] != C[j]:
            Q += 1
       
Q /= len(y)*(len(y)-1)/2
        
print('Quality (from 0 to 1):', Q)
# Out:
# Preprocessing of texts...
# Wiki-documents/Радиоэлектронные компоненты/Rectifying_diode.txt
# Wiki-documents/Радиоэлектронные компоненты/Diode.txt
# Wiki-documents/Радиоэлектронные компоненты/Diode_bridge.txt
# Wiki-documents/Радиоэлектронные компоненты/Hardware_register.txt
# Wiki-documents/Радиоэлектронные компоненты/Photodiode.txt
# Wiki-documents/Радиоэлектронные компоненты/Electronic_counter_of_signals.txt
# Wiki-documents/Радиоэлектронные компоненты/Phototransistor.txt
# Wiki-documents/Радиоэлектронные компоненты/Microcontroller.txt
# Wiki-documents/Радиоэлектронные компоненты/Thyristor.txt
# Wiki-documents/Радиоэлектронные компоненты/Photoresistor.txt
# Wiki-documents/Радиоэлектронные компоненты/TM.txt
# Wiki-documents/Радиоэлектронные компоненты/Opto-isolator.txt
# Wiki-documents/Радиоэлектронные компоненты/Transistor.txt
# Wiki-documents/Радиоэлектронные компоненты/Light-emitting_diode.txt
# Wiki-documents/Радиоэлектронные компоненты/Adder.txt
# Wiki-documents/Радиоэлектронные компоненты/Flip-flop.txt
# Wiki-documents/Радиоэлектронные компоненты/Phototyristor.txt
# Wiki-documents/Радиоэлектронные компоненты/TRIAC.txt
# Wiki-documents/Радиоэлектронные компоненты/Triode.txt
# Wiki-documents/Радиоэлектронные компоненты/Analogue_electronics.txt
# Wiki-documents/МРТ/Magnetic_resonanse_tomography.txt
# Wiki-documents/МРТ/Positron_emission_tomography.txt
# Wiki-documents/МРТ/Nuclear_magnetic_resonance_spectroscopy.txt
# Wiki-documents/МРТ/Diffusion_MRI.txt
# Wiki-documents/МРТ/Linear_tomography.txt
# Wiki-documents/МРТ/MR-antiography.txt
# Wiki-documents/МРТ/Electromagnetic_interaction.txt
# Wiki-documents/МРТ/Functional_magnetic_resonance_imaging.txt
# Wiki-documents/МРТ/КТ-antiography.txt
# Wiki-documents/МРТ/Computer_tomography.txt
# Wiki-documents/МРТ/Introscopy.txt
# Wiki-documents/МРТ/One_photone_emission_computer tomography.txt
# Wiki-documents/МРТ/Electronic_tomography.txt
# Wiki-documents/МРТ/Tomosyntes.txt
# Wiki-documents/МРТ/Optical_tomography.txt
# Wiki-documents/МРТ/Electron_beam_tomography.txt
# Wiki-documents/МРТ/Scintigraphy.txt
# Wiki-documents/МРТ/Magnetic_moment.txt
# Wiki-documents/МРТ/Nuclear_magnetic_resonanse.txt
# Wiki-documents/МРТ/Tomography.txt
# Wiki-documents/МРТ/Computer_tomography_high_resoution.txt
# Wiki-documents/ML/Overfitting.txt
# Wiki-documents/ML/Loss_function.txt
# Wiki-documents/ML/EM.txt
# Wiki-documents/ML/Neural_net_verbalization.txt
# Wiki-documents/ML/Theorem_of_convergence_of_perceptron.txt
# Wiki-documents/ML/Linear_regression.txt
# Wiki-documents/ML/SVM.txt
# Wiki-documents/ML/Genetic_algorithm.txt
# Wiki-documents/ML/Classification_task.txt
# Wiki-documents/ML/Random_Forest.txt
# Wiki-documents/ML/Cluster_analysis.txt
# Wiki-documents/ML/Superwised_learning.txt
# Wiki-documents/ML/Machine_learning.txt
# Wiki-documents/ML/Method_of_correction_error.txt
# Wiki-documents/ML/Backropagation.txt
# Wiki-documents/ML/Theory_of_pattern recognition.txt
# Wiki-documents/ML/Desision_trees.txt
# Wiki-documents/ML/Hierarchical_clusterization.txt
# Wiki-documents/ML/Deep_learning.txt
# Wiki-documents/ML/k-means.txt
# [[4.10000000e+01 5.30000000e+01 3.98101152e-08 2.00000000e+00]
#  [1.60000000e+01 2.00000000e+01 3.27791087e-07 2.00000000e+00]
#  [4.80000000e+01 5.80000000e+01 5.63172547e-07 2.00000000e+00]
#  [1.00000000e+00 2.20000000e+01 6.35902994e-07 2.00000000e+00]
#  [4.70000000e+01 5.10000000e+01 2.79782776e-06 2.00000000e+00]
#  [1.80000000e+01 2.70000000e+01 5.80502243e-06 2.00000000e+00]
#  [4.40000000e+01 4.90000000e+01 8.28000836e-06 2.00000000e+00]
#  [4.00000000e+00 1.30000000e+01 8.31649283e-06 2.00000000e+00]
#  [5.40000000e+01 6.50000000e+01 9.90593868e-06 3.00000000e+00]
#  [1.10000000e+01 1.70000000e+01 1.03009600e-05 2.00000000e+00]
#  [6.00000000e+00 4.00000000e+01 1.36829828e-05 2.00000000e+00]
#  [1.90000000e+01 2.10000000e+01 1.67346682e-05 2.00000000e+00]
#  [6.40000000e+01 6.60000000e+01 1.82664039e-05 4.00000000e+00]
#  [3.60000000e+01 3.80000000e+01 1.86740490e-05 2.00000000e+00]
#  [9.00000000e+00 1.20000000e+01 2.13315640e-05 2.00000000e+00]
#  [7.00000000e+00 1.50000000e+01 2.45014495e-05 2.00000000e+00]
#  [5.60000000e+01 6.30000000e+01 2.78004635e-05 3.00000000e+00]
#  [4.30000000e+01 5.00000000e+01 2.85342754e-05 2.00000000e+00]
#  [2.00000000e+00 2.60000000e+01 3.10832188e-05 2.00000000e+00]
#  [3.10000000e+01 3.50000000e+01 3.32599636e-05 2.00000000e+00]
#  [5.20000000e+01 6.00000000e+01 3.89713671e-05 2.00000000e+00]
#  [5.90000000e+01 6.10000000e+01 4.94097934e-05 3.00000000e+00]
#  [4.50000000e+01 6.90000000e+01 5.76557166e-05 4.00000000e+00]
#  [1.00000000e+01 7.30000000e+01 6.24354385e-05 5.00000000e+00]
#  [5.50000000e+01 6.70000000e+01 6.74995486e-05 3.00000000e+00]
#  [4.20000000e+01 7.80000000e+01 7.53261586e-05 3.00000000e+00]
#  [2.30000000e+01 2.50000000e+01 8.39423456e-05 2.00000000e+00]
#  [8.00000000e+00 7.50000000e+01 1.06732299e-04 3.00000000e+00]
#  [6.20000000e+01 8.00000000e+01 1.43180267e-04 4.00000000e+00]
#  [0.00000000e+00 7.20000000e+01 1.44144139e-04 3.00000000e+00]
#  [2.90000000e+01 7.10000000e+01 1.56855899e-04 3.00000000e+00]
#  [3.20000000e+01 3.70000000e+01 1.89859442e-04 2.00000000e+00]
#  [5.70000000e+01 8.10000000e+01 1.97185899e-04 3.00000000e+00]
#  [3.00000000e+00 7.60000000e+01 1.98184051e-04 3.00000000e+00]
#  [3.40000000e+01 7.40000000e+01 2.40952392e-04 3.00000000e+00]
#  [7.90000000e+01 8.40000000e+01 2.52030543e-04 7.00000000e+00]
#  [2.40000000e+01 8.80000000e+01 2.91088102e-04 4.00000000e+00]
#  [6.80000000e+01 9.00000000e+01 5.50852000e-04 5.00000000e+00]
#  [8.50000000e+01 9.30000000e+01 5.88145061e-04 6.00000000e+00]
#  [7.00000000e+01 9.70000000e+01 6.31133278e-04 6.00000000e+00]
#  [8.70000000e+01 9.20000000e+01 7.93927979e-04 4.00000000e+00]
#  [5.00000000e+00 3.00000000e+01 9.90904191e-04 2.00000000e+00]
#  [9.10000000e+01 9.50000000e+01 1.08203817e-03 6.00000000e+00]
#  [8.20000000e+01 8.60000000e+01 1.10635725e-03 6.00000000e+00]
#  [4.60000000e+01 7.70000000e+01 1.21030860e-03 4.00000000e+00]
#  [9.60000000e+01 9.80000000e+01 1.53392576e-03 1.20000000e+01]
#  [2.80000000e+01 1.01000000e+02 2.09099775e-03 5.00000000e+00]
#  [3.30000000e+01 3.90000000e+01 2.16431382e-03 2.00000000e+00]
#  [1.40000000e+01 9.40000000e+01 2.31945863e-03 4.00000000e+00]
#  [8.30000000e+01 1.05000000e+02 2.33368479e-03 8.00000000e+00]
#  [9.90000000e+01 1.04000000e+02 3.38205201e-03 1.20000000e+01]
#  [8.90000000e+01 1.03000000e+02 3.96049204e-03 1.00000000e+01]
#  [1.00000000e+02 1.06000000e+02 4.41042231e-03 1.80000000e+01]
#  [1.07000000e+02 1.12000000e+02 1.21274393e-02 1.50000000e+01]
#  [1.10000000e+02 1.11000000e+02 1.32001433e-02 2.00000000e+01]
#  [1.02000000e+02 1.08000000e+02 1.40287762e-02 4.00000000e+00]
#  [1.13000000e+02 1.14000000e+02 3.05088770e-02 3.30000000e+01]
#  [1.09000000e+02 1.16000000e+02 5.20661787e-02 8.00000000e+00]
#  [1.17000000e+02 1.18000000e+02 1.55810711e-01 4.10000000e+01]
#  [1.15000000e+02 1.19000000e+02 6.60594592e-01 6.10000000e+01]]
# 61
# Quality (from 0 to 1): 0.7737704918032787
